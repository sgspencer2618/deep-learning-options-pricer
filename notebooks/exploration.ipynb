# %%
import sys
import os
sys.path.append('..')

# Now you can import
from scripts import fetch_historical
from src import data_ingest
import data

# %%
import pandas as pd
import numpy as np

# %%
data_ingest.parse_options_data("AAPL", "2017-11-15")
# Out:
# Data saved to data/AAPL_2017-11-15_options.csv
#                contractID symbol  expiration  strike  type   last    mark  \
# 0     AAPL171117C00002500   AAPL  2017-11-17     2.5  call  80.00  166.60
# 1     AAPL171117P00002500   AAPL  2017-11-17     2.5   put   0.00    0.01
# 2     AAPL171117C00005000   AAPL  2017-11-17     5.0  call  75.90  164.10
# 3     AAPL171117P00005000   AAPL  2017-11-17     5.0   put   0.00    0.01
# 4     AAPL171117C00007500   AAPL  2017-11-17     7.5  call  76.38  161.60
# ...                   ...    ...         ...     ...   ...    ...     ...
# 1373  AAPL200117P00240000   AAPL  2020-01-17   240.0   put  35.78   74.25
# 1374  AAPL200117C00250000   AAPL  2020-01-17   250.0  call   5.75    5.90
# 1375  AAPL200117P00250000   AAPL  2020-01-17   250.0   put  40.10   82.30
# 1376  AAPL200117C00260000   AAPL  2020-01-17   260.0  call   2.80    5.25
# 1377  AAPL200117P00260000   AAPL  2020-01-17   260.0   put   0.00   91.75
#
# ...
